# %%
import os

os.chdir("..")
print(f"Changed working directory to: {os.getcwd()}")
# Out:
# Changed working directory to: /Users/gabriel.torres/Nextcloud/Development/Pro5D/FlareSense

# %%
import matplotlib.pyplot as plt
from src.api import FlareDetection

detector = FlareDetection("33ad4d2d26fe416db7dd9eda2e4fd2fb", device="cpu")
# Out:
# ...
# 2024/01/15 15:24:32 WARNING mlflow.pytorch: Stored model version '2.1.2+cu121' does not match installed PyTorch version '2.1.1'

# %%
data, minute_by_minute, fig = detector.detect("2024-01-04 00:00:00", "Australia-ASSA_62", window_length="2h")
plt.show()
# Out:
# Detecting flares from 2024-01-04 00:00:00 to 2024-01-04 02:00:00 on Australia-ASSA_62
# ...
